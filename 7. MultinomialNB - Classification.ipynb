# %%
import pandas as pd

# %%
dataset=pd.read_csv('CKD.csv')

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset.shape
# Out:
# (399, 25)

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
indep.shape
# Out:
# (399, 27)

# %%
dep
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 394    1
# 395    1
# 396    1
# 397    1
# 398    0
# Name: classification_yes, Length: 399, dtype: int32

# %%
# split into training set and test

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
# We didn't standardize the data because, MultinomialNB only works with non-negative features (counts / frequencies).
# If we use StandardScaler, we will create negatives.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
param_grid = param_grid = {'alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0], 'fit_prior': [True, False]}

grid = GridSearchCV(MultinomialNB(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')

# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=MultinomialNB(), n_jobs=-1,
#              param_grid={'alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],
#                          'fit_prior': [True, False]},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning
# print(grid.best_params_)
clf=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, grid_predictions)

# print classification report
from sklearn.metrics import classification_report
clf_report=classification_report(y_test, grid_predictions)

# %%
# sample to check f1 macro value
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'alpha': 0.01, 'fit_prior': True}: 0.888737824982843

# %%
print("MultinomialNB_Confusion Matrix:\n",cm)
# Out:
# MultinomialNB_Confusion Matrix:
#  [[50  1]
#  [14 68]]

# %%
print("MultinomialNB_Classification_Report:\n",clf_report)
# Out:
# MultinomialNB_Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.98      0.87        51
#            1       0.99      0.83      0.90        82
#
#     accuracy                           0.89       133
#    macro avg       0.88      0.90      0.89       133
# weighted avg       0.91      0.89      0.89       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.947871831659493

# %%
table=pd.DataFrame.from_dict(clf)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.065495      0.022457         0.005066        0.000000         0.01
# 1        0.021663      0.020149         0.004731        0.001791         0.01
# 2        0.004364      0.000203         0.003260        0.000387         0.10
# 3        0.003567      0.000509         0.003806        0.000241         0.10
# 4        0.004001      0.000547         0.002902        0.000487         0.50
# 5        0.002350      0.001336         0.001643        0.002445         0.50
# 6        0.005458      0.003175         0.003617        0.001887         1.00
# 7        0.004089      0.001556         0.002849        0.001187         1.00
# 8        0.002952      0.000897         0.003429        0.000775         5.00
# 9        0.003870      0.000701         0.003663        0.000602         5.00
# 10       0.003747      0.000300         0.003598        0.000600        10.00
# ...

# %%
age_input=float(input("Age:"))
bp_input=float(input("bp:"))
al_input=int(input("al:"))
su_input=int(input("su:"))
bgr_input=float(input("bgr:"))
bu_input=float(input("bu:"))
sc_input=float(input("sc:"))
sod_input=float(input("sod:"))
pot_input=float(input("pot:"))
hrmo_input=float(input("hrmo:"))
pcv_input=float(input("pvc:"))
wc_input=float(input("wc:"))
rc_input=float(input("rc:"))
sg_b_input=int(input("sg_b 1 or 0:"))
sg_c_input=int(input("sg_c 1 or 0:"))
sg_d_input=int(input("sg_d 1 or 0:"))
sg_e_input=int(input("sg_e 1 or 0:"))
rbc_normal_input=int(input("rbc_normal 1 or 0:"))
pc_normal_input=int(input("pc_normal 1 or 0:"))
pcc_present_input=int(input("pcc_present 1 or 0:"))
ba_present_input=int(input("ba_present 1 or 0:"))
htn_yes_input=int(input("htn_yes 1 or 0:"))
dm_yes_input=int(input("dm_yes 1 or 0:"))
cad_yes_input=int(input("cad_yes 1 or 0:"))
appet_yes_input=int(input("appet_yes 1 or 0:"))
pe_yes_input=int(input("pe_yes 1 or 0:"))
ane_yes_input=int(input("ane_yes 1 or 0:"))
# Out:
# Age: 25
# bp: 458
# al: 84
# su: 51
# bgr: 12
# bu: 456
# sc: 123
# sod: 789
# pot: 258
# hrmo: 369
# pvc: 147
# wc: 146
# rc: 3.2
# sg_b 1 or 0: 1
# sg_c 1 or 0: 1
# sg_d 1 or 0: 1
# sg_e 1 or 0: 1
# rbc_normal 1 or 0: 1
# pc_normal 1 or 0: 1
# pcc_present 1 or 0: 1
# ba_present 1 or 0: 1
# htn_yes 1 or 0: 1
# dm_yes 1 or 0: 1
# cad_yes 1 or 0: 0
# appet_yes 1 or 0: 0
# pe_yes 1 or 0: 0
# ane_yes 1 or 0: 0

# %%
Future_Prediction = grid.predict([[age_input, bp_input, al_input, su_input, bgr_input, bu_input, 
                                   sc_input, sod_input, pot_input, hrmo_input, pcv_input, wc_input, 
                                   rc_input, sg_b_input, sg_c_input, sg_d_input, sg_e_input, rbc_normal_input, 
                                   pc_normal_input, pcc_present_input, ba_present_input, htn_yes_input, dm_yes_input, 
                                   cad_yes_input, appet_yes_input, pe_yes_input, ane_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
# C:\Users\Default.DESKTOP-73FCCDO\Documents\Installations\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
